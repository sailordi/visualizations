# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame({
'name':['christopher','marion','maria','mia','clement','randy','remi'],
'age':[70,30,22,19,45,33,20],
'gender':['M','F','F','F','M','M','M'],
'state':['california','dc','california','dc','california','new york','porto'],
'num_children':[4,2,1,0,3,1,0],
'num_pets':[5,1,0,2,2,2,3]
})

# %%
# Creating the scatter plot using Pandas' plot method
ax = df.plot(kind='scatter', x='age', y='num_children', color='red', figsize=(12, 6))

# Setting the labels
ax.set_xlabel('Age', color='purple')
ax.set_ylabel('Number of Children', color='purple')
plt.title('Relationship Between Age and Number of Children', color='purple')

print("Question 1")
plt.show()
# Out:
# Question 1
